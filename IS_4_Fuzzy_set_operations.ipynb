# %% [markdown]
# #**ARCHISHA SINHA**
# ##Domain: Intelligent Systems- 2
# ##Topic: Fuzzy set operations

# %% [markdown]
# #Fuzzy Sets:
#
# Fuzzy refers to something that is unclear or vague. Hence, Fuzzy Set is a Set where every key is associated with value, which is between 0 to 1 based on the certainty. This value is often called as degree of membership.
# Fuzzy logic is an organized method for dealing with imprecise data. It is a multivalued logic that allows intermediate values to be defined between conventional solutions. In classical set theory, the membership of elements in a set is assessed in binary terms according to a bivalent condition — an element either belongs or does not belong to the set. By contrast, fuzzy set theory permits the gradual assessment of the membership of elements in a set; this is described with the aid of a membership function valued in the real unit interval [0, 1].
# Bivalent Set Theory can be somewhat limiting if we wish to describe a 'humanistic' problem mathematically. For example, Fig 1 below illustrates bivalent sets to characterize the temperature of a room. The most obvious limiting feature of bivalent sets that can be seen clearly from the diagram is that they are mutually exclusive - it is not possible to have membership of more than one set. Clearly, it is not accurate to define a transition from a quantity such as 'warm' to 'hot' by the application of one degree Fahrenheit of heat. In the real world a smooth (unnoticeable) drift from warm to hot would occur.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Basic operations on Fuzzy Sets:
#
# ###Consider two fuzzy sets A and B.
# 1. Union:
# Consider Y be the Union of them, then for every member of A and B, Y will be:
#
# **Degree of membership(Y)= max(degree of membership(A), degree of membership(B))**
#
# 2. Intersection:
# Consider Y be the Intersection of them, then for every member of A and B, Y will be:
#
# **Degree of membership(Y)= min(degree of membership(A), degree of membership(B))**
#
# 3. Complement:
# Consider Y be the Complement of it, then for every member of A, Y will be:
#
# **Degree of membership(Y)= 1 – degree of membership(A)**
#
# 4. Difference:
# Consider Y be the Intersection of them, then for every member of A and B, Y will be:
# **Degree of membership(Y)= min(degree of membership(A), 1- degree of membership(B))**

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PAPER 1:**
#
# Paper Title: Performance evaluation of artificial intelligence paradigms—Artificial Neural networks, fuzzy logic, and adaptive neuro-fuzzy Inference system for Flood Prediction
#
# https://www.proquest.com/docview/2532438606?pq-origsite=gscholar&fromopenview=true&sourcetype=Scholarly%20Journals
#
# AI application: Flood prediction
#
# Algorithms used: Artificial Neural Network
#
# Key concepts: This study explores the possibilities of modeling stream flow especially the flood extremities using the artificial intelligence techniques, employing a holistic approach, taking into account hydrological, and geomorphological attributes of the river system to improve the flood early warning system for mitigating the impact of the flood disasters in future. The developed AI
# models use historical data to make the predictions, hence are less cost-intensive and do not require the dreary calibration of the model parameters vital in the development of the theoretical or the physically dependent hydrological models
#
#
#
# **PAPER 2**:
#
# Paper Title: Comparison of artificial neural network, fuzzy logic and genetic algorithm for cutting temperature and surface roughness prediction during the face-milling process
#
# https://www.researchgate.net/publication/343469437_Comparison_of_artificial_neural_network_fuzzy_logic_and_genetic_algorithm_for_cutting_temperature_and_surface_roughness_prediction_during_the_face_milling_process
#
# AI application: Face Milling Process
#
# Algorithms used: Artificial Neural Network
#
# Key concepts: This paper shows the possibility of applying artificial intelligence methods in
# milling, as one of the most common machining operations. The main goal of
# the research is to obtain reliable intelligent models for selected output characteristics of the milling process.
#
#
#
# **PAPER 3:**
#
# Paper Title: Market revenue prediction and error analysis of products based on fuzzy logic and artifcial intelligence algorithms
#
# https://link.springer.com/article/10.1007/s12652-019-01650-2
#
# AI application: Market revenue prediction
#
# Algorithms used: Artificial Neural Network
#
# Key concepts: Neural networks can approximate the neuron information of all quantitative or qualitative nonlinear relationship, any complex is stored in the potential distribution in the network. It has strong robustness and fault tolerance, using the parallel distribution processing method, making quick lots of computing is possible. The mature prediction method in artifcial intelligence, or the neural network method to forecast, this kind of algorithm has theoretical support to mature, reliable predictions of the information.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %%
import numpy as np

# %%
A = {"a": 0.4, "b": 0.2, "c": 0.7, "d": 0.3, "e": 0.5}
B = {"a": 0.7, "b": 0.6, "c": 0.3, "d": 0.5, "e": 0.2}

# %% [markdown]
# Union of Two Fuzzy Sets

# %%
def union_dicts(A, B):
    union_AB = A.copy()
    union_AB.update(B)
    return union_AB


union_result = union_dicts(A, B)
print("Union Of sets is: ",union_result)
# Out:
# Union Of sets is:  {'a': 0.7, 'b': 0.6, 'c': 0.3, 'd': 0.5, 'e': 0.2}

# %% [markdown]
# Intersection of Two Fuzzy Sets

# %%
intersection = {key: A[key] for key in A.keys() & B.keys()}

print("Intersection of dictionaries A and B:", intersection)
# Out:
# Intersection of dictionaries A and B: {'a': 0.4, 'd': 0.3, 'e': 0.5, 'b': 0.2, 'c': 0.7}

# %% [markdown]
# Complement of Two Fuzzy Sets

# %%
# Finding the complement of each probability
complement_A = {key: 1 - value for key, value in A.items()}
complement_B = {key: 1 - value for key, value in B.items()}

# Print the original and complement dictionaries
print("Original Dictionary A:", A)
print("Complement Dictionary A:", complement_A)
print("Original Dictionary B:", B)
print("Complement Dictionary B:", complement_B)
# Out:
# Original Dictionary A: {'a': 0.4, 'b': 0.2, 'c': 0.7, 'd': 0.3, 'e': 0.5}
# Complement Dictionary A: {'a': 0.6, 'b': 0.8, 'c': 0.30000000000000004, 'd': 0.7, 'e': 0.5}
# Original Dictionary B: {'a': 0.7, 'b': 0.6, 'c': 0.3, 'd': 0.5, 'e': 0.2}
# Complement Dictionary B: {'a': 0.30000000000000004, 'b': 0.4, 'c': 0.7, 'd': 0.5, 'e': 0.8}

# %% [markdown]
# Difference between the Two Fuzzy Sets

# %%
# Finding the difference between the values of corresponding keys
difference_result = {key: abs(A[key] - B[key]) for key in A}

# Print the original dictionaries and the difference result
print("Dictionary A:", A)
print("Dictionary B:", B)
print("Difference Result:", difference_result)
# Out:
# Dictionary A: {'a': 0.4, 'b': 0.2, 'c': 0.7, 'd': 0.3, 'e': 0.5}
# Dictionary B: {'a': 0.7, 'b': 0.6, 'c': 0.3, 'd': 0.5, 'e': 0.2}
# Difference Result: {'a': 0.29999999999999993, 'b': 0.39999999999999997, 'c': 0.39999999999999997, 'd': 0.2, 'e': 0.3}

# %% [markdown]
# ##Observations and Learning:
# Fuzzy logic allows for gradual, overlapping truth values, accommodating degrees of uncertainty and imprecision, while traditional Boolean logic relies on crisp, binary true/false distinctions without considering degrees of truth. Fuzzy logic provides a more flexible framework for modeling real-world systems with ambiguous or incomplete information.

# %% [markdown]
# ##Conclusion:
#
# Fuzzy logic provides a flexible approach for handling uncertainty and imprecision in decision-making, allowing for nuanced reasoning and more realistic modeling in various fields. Its ability to manage vague boundaries enhances system adaptability and tolerance to incomplete information.
